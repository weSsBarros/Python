# %% [markdown]
# Primeira parte
# Até abertura do link

# %%
import pyautogui
import time
import pandas
import pyperclip

link = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyautogui.PAUSE = 0.3

pyautogui.press('win')
pyautogui.write('Chrome')
pyautogui.press('enter')
time.sleep(1.5)
pyautogui.write(link)
pyautogui.press('enter')

# %% [markdown]
# Acessando a base de dados
# Point(x=396, y=457)

# %%
time.sleep(3)
pyautogui.click(396, 457, clicks=2)
time.sleep(2) 
pyautogui.click(501, 455)
time.sleep(1)
pyautogui.click(560, 549)

# %% [markdown]
# Trabalhando com Base de Dados

# %%
caminho = r"C:\Users\Administrator\Downloads\Vendas - Dez.xlsx"
tabela = pandas.read_excel(caminho)

faturamento = tabela["Valor Final"].sum()

quantidade_produtos = tabela["Quantidade"].sum()

print(faturamento)
print(quantidade_produtos)
# Out:
# 2917311
# 15227

# %% [markdown]
# Criação do sistema do Email

# %%
pyautogui.click(365, 62)
pyautogui.write('https://mail.google.com/')
pyautogui.press('enter')
time.sleep(5)
pyautogui.click(31, 213)
pyautogui.write('destinatario@gmail.com')
pyautogui.press('tab')
#pyautogui.press('tab')

pyperclip.copy('Relatório de Vendas')
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('tab')

texto = f"""
Prezados,

Segue o relatório de vendas de hoje.

Faturamento: R${faturamento:,.2f}
Quantidade de produtos vendidos: {quantidade_produtos:,}

Qualquer dúvida estou à disposição.
Abs,
Lira Python
"""
pyperclip.copy(texto)
pyautogui.hotkey('ctrl', 'v')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 20
#      16
#      17 Segue o relatório de vendas de hoje.
#      18
#      19 Faturamento: R${faturamento:,.2f}
# ---> 20 Quantidade de produtos vendidos: {qtde_produtos:,}
#      21
#      22 Qualquer dúvida estou à disposição.
#      23 Abs,
#
# NameError: name 'qtde_produtos' is not defined

# %%
# Descobrindo posição do mouse

time.sleep(3)
print(pyautogui.position())
# Out:
# Point(x=31, y=213)
